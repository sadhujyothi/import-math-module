# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
hex(25)
# Out:
# '0x19'

# %%
# 6 type of bitwise 

- complement
- and
- or
- xor (xclusive or)
- left shift <<
- right shift >>

# %%
~12
# Out:
# -13

# %%
~3
# Out:
# -4

# %%
# bitwise and operator

# %%
12 & 13
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
1 & 0
# Out:
# 0

# %%
1 | 0
# Out:
# 1

# %%
12^13
# Out:
# 1

# %%
1 ^ 2
# Out:
# 3

# %%
40 ^ 34
# Out:
# 10

# %%
print(bin(40))
print(bin(34))
# Out:
# 0b101000
# 0b100010

# %%
bin(10)
# Out:
# '0b1010'

# %%
10<<1
# Out:
# 20

# %%
10<<2
# Out:
# 40

# %%
bin(10)
# Out:
# '0b1010'

# %%
name1 = 'fine' 
name1
# Out:
# 'fine'

# %%
name1[1:]
# Out:
# 'ine'

# %%
'd' + name1[1:]
# Out:
# 'dine'

# %% [markdown]
# Integer variable

# %%
age = 25
print(age)
# Out:
# 25

# %% [markdown]
# String variable

# %%
name = "Alice"
print(name)
# Out:
# Alice

# %% [markdown]
# Float Variable

# %%
price = 19.99
print(price)
# Out:
# 19.99

# %% [markdown]
# Boolean variable

# %%
is_active = True
print(is_active)
# Out:
# True

# %% [markdown]
# storing and printing a value

# %%
x = 10
print(x)
# Out:
# 10

# %% [markdown]
# Using variable in Expressions

# %%
a = 5
b = 3
result = a+b
print(result)
# Out:
# 8

# %% [markdown]
# Changing the value of a variable

# %%
score = 50
print(score)
# Out:
# 50

# %%
score = 100
print(score)
# Out:
# 100

# %% [markdown]
# Concatenating strings

# %%
first_name = "jyothi"
last_name = "sadhu"
full_name = first_name +" " + last_name
print(full_name)
# Out:
# jyothi sadhu

# %% [markdown]
# Using variable in a caluculation

# %%
length = 10
width = 5
area = length * width
print(area)
# Out:
# 50

# %% [markdown]
# Reassigning values to variables

# %%
x = 10
print(x)
# Out:
# 10

# %%
x = 20
print(x)
# Out:
# 20

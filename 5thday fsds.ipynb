# %%
i = 5
i
# Out:
# 5

# %%
type(i)
int
# Out:
# int

# %%
f=110.34
f
# Out:
# 110.34

# %%
type(f)
# Out:
# float

# %%
exponential function

# %%
2e0
# Out:
# 2.0

# %% [markdown]
# 2e1

# %%
-3e2
# Out:
# -300.0

# %% [markdown]
# 4e3

# %%
2.4e2
# Out:
# 240.0

# %% [markdown]
# -3e2

# %%
boolean

# %% [raw]
# t=true
# f=false
# print(t+f)
# print(t-f)
# print(t*f)
# print(t/f)

# %%
c
